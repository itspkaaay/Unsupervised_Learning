# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
x,y=make_blobs(n_samples=500,n_features=2,centers=5,cluster_std=1)

# %%
x=np.array(x)
y=np.array(y)

# %%
plt.style.use('seaborn')
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %%
plt.scatter(x[:,0],x[:,1])

# %%
clusters ={
    
}
colours=["green","blue","yellow","red","black"]
def distance(v1,v2):
    return np.sqrt(np.sum((v1-v2)**2))

def init_clusters(clusters,k=5):
    for kx in range(k):
        cluster={
            'color': colours[kx],
            'points': [],
            "mean" : 10*np.random.random((x.shape[1]))
        }
        clusters[kx]= cluster
    return clusters

# %%
def kmeans(clusters,k=5):
    
    for ix in range(x.shape[0]):
        dist=[]
        
        for kx in range(k):
            dist.append(distance(x[ix],clusters[kx]['mean']))
        
        minIndex= np.argmin(dist)
        clusters[minIndex]['points'].append(x[ix])
    
    plotClusters(clusters)
    for kx in range(k):
        u=np.array([0.0,0.0])
        for point in clusters[kx]['points']:
            u+=np.array(point)
        
        if(len(clusters[kx]['points'])!=0):
            u/= len(clusters[kx]['points'])
            clusters[kx]['mean']=u
        else:
            pass
        print(np.array(clusters[kx]['points']).shape)
        clusters[kx]['points']=[]
        
    return clusters

# %%
def plotClusters(clusters,k=5):

    for kx in range(5):
        temp= np.array(clusters[kx]['points'])
        try:
            x_axis= temp[:,0]
            y_axis= temp[:,1]
            plt.scatter(x_axis,y_axis,marker='o',color=clusters[kx]['color'])
            
        except:
            pass
    
        plt.scatter(clusters[kx]['mean'][0],clusters[kx]['mean'][1],marker='x',
                    color=clusters[kx]['color'])
    plt.show()

# %%
clusters= init_clusters(clusters)

# %%
print(clusters)
# Out:
# {0: {'color': 'green', 'points': [], 'mean': array([3.01797004, 3.37640082])}, 1: {'color': 'blue', 'points': [], 'mean': array([2.4395522 , 7.58106934])}, 2: {'color': 'yellow', 'points': [], 'mean': array([0.70185343, 7.05319742])}, 3: {'color': 'red', 'points': [], 'mean': array([7.39263065, 5.32320542])}, 4: {'color': 'black', 'points': [], 'mean': array([0.07758225, 8.45389501])}}

# %%
clusters= kmeans(clusters)
# Out:
# (50, 2)
# (49, 2)
# (165, 2)
# (60, 2)
# (176, 2)

# %%
print(clusters)
# Out:
# {0: {'color': 'green', 'points': [], 'mean': array([1.34619032, 3.43999393])}, 1: {'color': 'blue', 'points': [], 'mean': array([3.17156477, 8.46882563])}, 2: {'color': 'yellow', 'points': [], 'mean': array([-5.10085132,  3.27486854])}, 3: {'color': 'red', 'points': [], 'mean': array([5.89498773, 5.64742888])}, 4: {'color': 'black', 'points': [], 'mean': array([-5.31344359,  6.98266036])}}

# %%
clusters= kmeans(clusters)
# Out:
# (38, 2)
# (102, 2)
# (178, 2)
# (95, 2)
# (87, 2)

# %%
print(clusters)
# Out:
# {0: {'color': 'green', 'points': [], 'mean': array([-1.07312007,  3.33970245])}, 1: {'color': 'blue', 'points': [], 'mean': array([1.56910107, 9.31077028])}, 2: {'color': 'yellow', 'points': [], 'mean': array([-6.28034549,  3.18031367])}, 3: {'color': 'red', 'points': [], 'mean': array([5.37457176, 5.52988223])}, 4: {'color': 'black', 'points': [], 'mean': array([-8.18785807,  6.05836219])}}

# %%
kmeans(clusters)
# Out:
# {0: {'color': 'green',
#   'points': [],
#   'mean': array([-4.18480336, -3.80379155])},
#  1: {'color': 'blue', 'points': [], 'mean': array([ 3.15189412, -5.3181034 ])},
#  2: {'color': 'yellow', 'points': [], 'mean': array([6.28127724, 4.4951954 ])},
#  3: {'color': 'red', 'points': [], 'mean': array([ 9.73972666, -4.0688133 ])},
#  4: {'color': 'black', 'points': [], 'mean': array([4.2275252 , 9.16195495])}}

# %%
kmeans(clusters)
# Out:
# (98, 2)
# (100, 2)
# (90, 2)
# (100, 2)
# (112, 2)
# {0: {'color': 'green',
#   'points': [],
#   'mean': array([-2.10391885,  3.45654655])},
#  1: {'color': 'blue', 'points': [], 'mean': array([1.40643564, 9.3706136 ])},
#  2: {'color': 'yellow',
#   'points': [],
#   'mean': array([-7.5195452 ,  2.70407964])},
#  3: {'color': 'red', 'points': [], 'mean': array([5.30978539, 5.58790478])},
#  4: {'color': 'black',
#   'points': [],
#   'mean': array([-8.83098281,  5.51034688])}}

# %%
kmeans(clusters)
# Out:
# (100, 2)
# (100, 2)
# (90, 2)
# (100, 2)
# (110, 2)
# {0: {'color': 'green',
#   'points': [],
#   'mean': array([-2.14382375,  3.45488201])},
#  1: {'color': 'blue', 'points': [], 'mean': array([1.40643564, 9.3706136 ])},
#  2: {'color': 'yellow',
#   'points': [],
#   'mean': array([-7.66130998,  2.68649888])},
#  3: {'color': 'red', 'points': [], 'mean': array([5.30978539, 5.58790478])},
#  4: {'color': 'black',
#   'points': [],
#   'mean': array([-8.80102652,  5.56358617])}}

# %%
kmeans(clusters)
# Out:
# (100, 2)
# (100, 2)
# (93, 2)
# (100, 2)
# (107, 2)
# {0: {'color': 'green',
#   'points': [],
#   'mean': array([-2.14382375,  3.45488201])},
#  1: {'color': 'blue', 'points': [], 'mean': array([1.40643564, 9.3706136 ])},
#  2: {'color': 'yellow',
#   'points': [],
#   'mean': array([-7.74034213,  2.70568287])},
#  3: {'color': 'red', 'points': [], 'mean': array([5.30978539, 5.58790478])},
#  4: {'color': 'black',
#   'points': [],
#   'mean': array([-8.76428969,  5.62757824])}}

# %%
kmeans(clusters)
# Out:
# (100, 2)
# (100, 2)
# (93, 2)
# (100, 2)
# (107, 2)
# {0: {'color': 'green',
#   'points': [],
#   'mean': array([-2.14382375,  3.45488201])},
#  1: {'color': 'blue', 'points': [], 'mean': array([1.40643564, 9.3706136 ])},
#  2: {'color': 'yellow',
#   'points': [],
#   'mean': array([-7.74034213,  2.70568287])},
#  3: {'color': 'red', 'points': [], 'mean': array([5.30978539, 5.58790478])},
#  4: {'color': 'black',
#   'points': [],
#   'mean': array([-8.76428969,  5.62757824])}}

# %% [markdown]
# # THE LAST TWO ITERATIONS STOP WITH SAME SIZES OF POINTS ASSOCIATED TO EACH CLUSTER WHICH IS THE STOPPING CONDITION
