# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_moons

# %% [markdown]
# # K-Means

# %%
x,y= make_moons

# %%
x,y= make_moons(n_samples=200, noise=0.15)

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %%
km= KMeans(n_clusters=2)

# %%
km.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels=km.labels_

# %%
centers= km.cluster_centers_
print(centers)
# Out:
# [[-0.21843645  0.63712743]
#  [ 1.18420619 -0.11563263]]

# %%
plt.style.use('seaborn')
plt.scatter(x[:,0],x[:,1],c=labels)
plt.scatter(centers[:,0],centers[:,1],marker='X', color='red')
plt.title("Clustering using KMeans")
plt.show()

# %%
plt.scatter(x[:,0],x[:,1],c=y)
plt.title('Actual Clusters')
plt.show()

# %% [markdown]
# Can be noticed that kmean doesnot work well when the data isnt linearly separable

# %% [markdown]
# # USING DBSCAN METHOD INSTEAD...

# %%
from sklearn.cluster import DBSCAN

# %%
dbs= DBSCAN?

# %%
dbs= DBSCAN(eps=0.20, min_samples=6)

# %%
print(dbs)
# Out:
# DBSCAN(algorithm='auto', eps=0.1, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=7, n_jobs=None, p=None)

# %%
prediction=dbs.fit_predict(x)
print(prediction)
# Out:
# [ 0  1  1 -1  0  1  1  0  1  1  0  1  0  1  0  1  2  0  0  3  1  1  1  1
#   3  1  1  0  0 -1  1  3  1  1  2  3  1  1  0 -1  0  0  0 -1  0  1  3  0
#  -1  3  0  3  1  1  1  0  2  0  1 -1  0  1 -1  3  1  3  3  1  1  1  0  3
#   0  1  0  1  0  1  0  3  3  2  0  2  0 -1  1  0  0  3  3  0  1  0  1  1
#   0  1  1  3  1  1  1  2  0  1  1  1  3  0  0  0  3  1 -1  1  1  0  1  1
#   1  1  3  3  1  3  0  3  1  1  3  1  1  3  1  1  0  3  0  2  1  1  0  1
#   1  0  0  0  3  0  2  1  3  3  1  1  0  1  1  1  1  0  2  1  1  2  0  0
#   1  1  0  0  0  0  1  0  0  0  3  1  0  1  1  0  1  2  0  3  3  0  1  0
#  -1  3  1  1  3  1  1  1]

# %%
plt.scatter(x[:,0],x[:,1],c=prediction)
